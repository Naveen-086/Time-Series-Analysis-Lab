# %%
import numpy as np
import pandas as %pdoc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/gold.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4718 entries, 0 to 4717
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4718 non-null   object
#  1   USD (AM)   4718 non-null   float64
#  2   USD (PM)   4682 non-null   float64
#  3   GBP (AM)   4718 non-null   float64
#  4   GBP (PM)   4682 non-null   float64
#  5   EURO (AM)  4718 non-null   float64
#  6   EURO (PM)  4682 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 258.1+ KB

# %%
df.head()
# Out:
#          Date  USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# 0  2001-01-02    272.80    271.10   183.026   181.617    288.677    287.334
# 1  2001-01-03    269.00    267.15   178.916   177.390    281.823    281.655
# 2  2001-01-04    268.75    267.10   178.869   178.352    282.538    282.049
# 3  2001-01-05    268.00    267.40   178.488   178.148    280.775    280.882
# 4  2001-01-08    268.60    268.30   178.769   178.664    282.410    282.481

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['Return'] = df['USD (PM)'].pct_change()*100
df['Lagged_Return'] = df.Return.shift()
df = df.dropna()
# Out:
# <ipython-input-27-2f92addbe9cb>:1: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Return'] = df['USD (PM)'].pct_change()*100

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#          Date  USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)  \
# 2  2001-01-04    268.75     267.1   178.869   178.352    282.538    282.049
# 3  2001-01-05    268.00     267.4   178.488   178.148    280.775    280.882
# 4  2001-01-08    268.60     268.3   178.769   178.664    282.410    282.481
# 5  2001-01-09    267.75     267.0   179.855   179.195    284.507    283.590
# 6  2001-01-10    266.70     266.3   178.777   178.665    283.573    283.298
#
#      Return  Lagged_Return
# 2 -0.018716      -1.457027
# 3  0.112317      -0.018716
# 4  0.336574       0.112317
# 5 -0.484532       0.336574
# 6 -0.262172      -0.484532

# %%
features = df.iloc[:,:]
features= features.drop('Return' , axis = 1)

# %%
label = df['Return']

# %%
features.plot()
# Out:
# <Axes: >
